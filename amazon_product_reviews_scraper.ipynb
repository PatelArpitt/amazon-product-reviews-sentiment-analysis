# %%
import requests
import urllib
from bs4 import BeautifulSoup
import pandas as pd
import csv
from itertools import cycle
import traceback

# %%
# This cell only to be used when origin IP of the user is blocked. This cell uses a dictionary of free proxies to make multiple get requests from it.
proxies = {
    'http://131.100.48.236:999', 
    'http://103.172.70.139:9191', 
    'http://144.217.119.85:3207', 
    'http://167.114.96.27:9300', 
    'http://158.69.185.37:3129'
}
 
proxy_pool = cycle (proxies)
url = input('Please enter the Amazon Product URL here:')

for i in range (1,6):
# Get a proxy from the pool
    proxy = next (proxy_pool)
    print ("Request #%d"%i)
    try:
        req = requests.get(url, proxies = { "http": proxy, "https": proxy }, timeout = 30)
        print (response.json())
    except requests.exceptions.Timeout:
        print ('Connection timeout, please retry or wait for some time before retrying.')
    except requests.exceptions.TooManyRedirects:
        print ('Too many redirects, please check the URL and try again.')
    except requests.exceptions.RequestException as e:
        print ('Fatal error ::: ', e)
        raise SystemExit(e)
    except:
    # Most free proxies will often get connection errors. You will need to retry the request using another proxy.  
        print("Skipping proxy. Connection error")
    else:
        print ('URL is good!')

# %%
# [WORK IN PROGRESS] This cell only to be used when user wants to add multiple products into reviews and wants to review all of them together.

# With multiple user inputs, we can add upto 5 products (for efficiency of output reviewing) from the user through input box.

# input('Please enter the Amazon Product URL here:')
# # two options will be provided to the user to continue adding products or to display output.

list_of_urls = ['https://www.amazon.com/Apple-Watch-Cellular-Midnight-Aluminum/product-reviews/B09PB1PTH8/ref=cm_cr_othr_d_show_all_btm?ie=UTF8&reviewerType=all_reviews',
'https://www.amazon.com/Apple-Watch-Cellular-Midnight-Aluminum/product-reviews/B09PB1PTH8/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2',
'https://www.amazon.com/Apple-Watch-Cellular-Midnight-Aluminum/product-reviews/B09PB1PTH8/ref=cm_cr_getr_d_paging_btm_next_3?ie=UTF8&reviewerType=all_reviews&pageNumber=3',
'https://www.amazon.com/Apple-Watch-Cellular-Midnight-Aluminum/product-reviews/B09PB1PTH8/ref=cm_cr_getr_d_paging_btm_next_4?ie=UTF8&reviewerType=all_reviews&pageNumber=4',
'https://www.amazon.com/Apple-Watch-Cellular-Midnight-Aluminum/product-reviews/B09PB1PTH8/ref=cm_cr_getr_d_paging_btm_next_5?ie=UTF8&reviewerType=all_reviews&pageNumber=5']

name = []
review = []
data_string = ""

for url in list_of_urls: 
    params = { 'api_key': "57ebc5f03ab018912f6d04cb2b5a0ccc", 'url': url }
    response = requests.get('http://api.scraperapi.com/', params = urllib.parse.urlencode(params))
    soup = BeautifulSoup(response.text, 'html.parser')

    for item in soup.find_all("span", class_="a-profile-name"):
      data_string = data_string + item.get_text()
      name.append(data_string)
      data_string = ""  
    
    for item in soup.find_all("span", {"data-hook": "review-body"}):
      data_string = data_string + item.get_text()
      review.append(data_string)
      data_string = ""

# %%
# url = input('Please enter the Amazon Product URL here:')
# url = input('Please enter the Amazon Product URL here:')
# url = 'https://www.amazon.ca/Gaming-Keyboard-Backlit-Chromebook-Laptop/product-reviews/B08JPYTS6J/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'
url = 'https://www.amazon.ca/Gaming-Keyboard-Backlit-Chromebook-Laptop/product-reviews/B08JPYTS6J/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2'

try:
    req = requests.get(url)
except requests.exceptions.Timeout:
    print ('Connection timeout, please retry or wait for some time before retrying.')
except requests.exceptions.TooManyRedirects:
    print ('Too many redirects, please check the URL and try again.')
except requests.exceptions.RequestException as e:
    print ('Fatal error ::: ', e)
    raise SystemExit(e)
else:
    print ('URL is good!')

    names = []
    review_titles = []
    review_contents = []
    date_infos = []
    ratings = []
    # data_string = ""

    params = { 'api_key': "57ebc5f03ab018912f6d04cb2b5a0ccc", 'url': url }
    response = requests.get('http://api.scraperapi.com/', params = urllib.parse.urlencode(params))
    soup = BeautifulSoup(response.text, 'html.parser')

    # for i, item in enumerate(soup.find_all("span", class_="a-profile-name")):
    #   name.append(item.get_text())
    #   print('profile-name ::: ', i, item.get_text())

    # for j, item in enumerate(soup.find_all("span", {"data-hook": "review-title"})):
    #     review_title.append(item.get_text())
    #     print('review-title ::: ', j, item.get_text())

    # for k, item in enumerate(soup.find_all("span", {"data-hook": "review-body"})):
    #     reviews.append(item.get_text())
    #     print('review-body ::: ', k, item.get_text())

    for index, item in enumerate(soup.find_all("span", class_="a-profile-name")):
        if index > 1:
            data_string = data_string + item.get_text()
            names.append(data_string)
            print('profile-name ::: ', index, data_string)
            data_string = ""

    for index, item in enumerate(soup.find_all("a", attrs = {"data-hook": "review-title"})):
        # if index > 1:
        data_string = data_string + item.get_text()
        review_titles.append(data_string)
        print('review-title ::: ', index, data_string)
        data_string = ""

    for index, item in enumerate(soup.find_all("span", attrs = {"data-hook": "review-body"})):
        # if index > 1:
        data_string = data_string + item.get_text()
        review_contents.append(data_string)
        print('review-body ::: ', index, data_string)
        data_string = ""


    # Create the dictionary.
    reviews_dict = {'Reviewer Name': names, 'Review Title': review_titles, 'Review': review_contents}
    # Print the lengths of each list.  
    print('name', len(names), 'review_title', len(review_titles), 'reviews', len(review_contents))

# %%
url = input('Please enter the Amazon Product URL here:')

names = []
review_titles = []
review_contents = []
date_infos = []
ratings = []


page = 0
while True:
    page = page + 1
    print (f'page number: {page}')

    try:
        url = url.replace("/dp/", "/product-reviews/")
        params = { 'reviewerType': 'all', 'pageNumber': page }
        req = requests.get(url, params = urllib.parse.urlencode(params))
        print(req.url)
    except requests.exceptions.Timeout:
        print ('Connection timeout, please retry or wait for some time before retrying.')
    except requests.exceptions.TooManyRedirects:
        print ('Too many redirects, please check the URL and try again.')
    except requests.exceptions.RequestException as e:
        print ('Fatal error ::: ', e)
        raise SystemExit(e)
    else:
        print ('URL is good!')

        scraper_params = { 'api_key': '57ebc5f03ab018912f6d04cb2b5a0ccc', 'url': req.url }
        response = requests.get('http://api.scraperapi.com/', params = urllib.parse.urlencode(scraper_params))
        soup = BeautifulSoup(response.text, 'html.parser')

        customer_review_lst = soup.find("div", {"class": "a-section a-spacing-none reviews-content a-size-base"})
        customer_review_lst = BeautifulSoup('<br/>'.join([str(tag) for tag in customer_review_lst]), 'html.parser')

        name_lst = customer_review_lst.find_all("span", class_ = "a-profile-name")
        for name in name_lst:
            names.append(name.get_text())

        title_lst = customer_review_lst.find_all("a", attrs = {"data-hook": "review-title"})
        for title in title_lst:
            review_titles.append(title.get_text())

        content_lst = customer_review_lst.find_all("span", attrs = {"data-hook": "review-body"})
        for content in content_lst:
            review_contents.append(content.get_text())
            
        date_info_lst = customer_review_lst.find_all("span", attrs = {"data-hook": "review-date"})
        for date in date_info_lst:
            date_infos.append(date.get_text().split('on ')[1])

        rating_lst = customer_review_lst.find_all("i", attrs = {"data-hook": "review-star-rating"})
        for rating in rating_lst:
            ratings.append(rating.get_text()[:1])

        reviews_dict = {'Reviewer Name': names, 'Review Title': review_titles, 'Review Content': review_contents, 'Date Info': date_infos, 'Rating': ratings}
        print('names', len(names), 'review_title', len(review_titles), 'reviews', len(review_contents), 'date_info', len(date_infos), 'rating', len(ratings))

        if (customer_review_lst.find("li", {"class": "a-disabled a-last"})):
            print('all pages scrapped!')
            break
# Out:
# page number: 1
# https://www.amazon.ca/Gaming-Keyboard-Backlit-Chromebook-Laptop/product-reviews/B08JPYTS6J/ref=cm_cr_arp_d_product_top?ie=UTF8&th=1&reviewerType=all&pageNumber=1
# URL is good!
# names 10 review_title 10 reviews 10 date_info 10 rating 10
# page number: 2
# https://www.amazon.ca/Gaming-Keyboard-Backlit-Chromebook-Laptop/product-reviews/B08JPYTS6J/ref=cm_cr_arp_d_product_top?ie=UTF8&th=1&reviewerType=all&pageNumber=2
# URL is good!
# names 20 review_title 20 reviews 20 date_info 20 rating 20
# page number: 3
# https://www.amazon.ca/Gaming-Keyboard-Backlit-Chromebook-Laptop/product-reviews/B08JPYTS6J/ref=cm_cr_arp_d_product_top?ie=UTF8&th=1&reviewerType=all&pageNumber=3
# URL is good!
# names 26 review_title 26 reviews 26 date_info 26 rating 26
# all pages scrapped!

# %%
# Create a new dataframe.
df = pd.DataFrame.from_dict(reviews_dict, orient='index')
df.head()
# Out:
#                                                                0   \
# Reviewer Name                                     Amazon Customer
# Review Title                                         \nLove it!\n
# Review Content  \nI love this product! It’s cute and fun for s...
# Date Info                                        October 20, 2022
# Rating                                                          5
#
#                                                                1   \
# Reviewer Name                                             crystal
# Review Title                                        \nWork okay\n
# Review Content  \nNot the best quality but great for the price...
# Date Info                                      September 15, 2022
# Rating                                                          4
#
#                                                                2   \
# Reviewer Name                                         Brent ruffo
# Review Title                     \nVery good highly recommend 👍\n
# Review Content  \nThis product has been in my possession for 4...
# Date Info                                         August 12, 2022
# Rating                                                          5
#
#                                                                3   \
# Reviewer Name                                         Jaime Mason
# Review Title                         \nstandard 2000's keyboard\n
# Review Content  \nThe keys are raised extremely high, makes fo...
# Date Info                                        October 16, 2022
# Rating                                                          3
#
#                                                                4   \
# Reviewer Name                                               emily
# Review Title    \nPlastic keys not the best for some games but...
# Review Content                                           \nCute\n
# Date Info                                          April 24, 2022
# Rating                                                          4
#
#                                                                5   \
# Reviewer Name                                     Amazon Customer
# Review Title             \nUgh - didn't know it wasn't wireless\n
# Review Content  \nHad torn through the package only to discove...
# Date Info                                            June 7, 2022
# Rating                                                          3
#
#                                                                6   \
# Reviewer Name                                             Jessica
# Review Title                                 \nGreat additions!\n
# Review Content  \nThis keyboard and mouse duo was purchased to...
# Date Info                                       December 27, 2020
# Rating                                                          4
#
#                                                                7   \
# Reviewer Name                                              Ceetee
# Review Title                       \nPaint comes off after time\n
# Review Content  \nI’ve had this for about a year now and loved...
# Date Info                                             May 1, 2022
# Rating                                                          2
#
#                                                                8   \
# Reviewer Name                                          Dayna Keam
# Review Title                              \nNice cheap keyboard\n
# Review Content  \nWorks good for a cheaper keyboard. Love the ...
# Date Info                                       February 26, 2022
# Rating                                                          5
#
#                                                                9   ...  \
# Reviewer Name                                              Kaeley  ...
# Review Title                                          \nAmazing\n  ...
# Review Content  \nSuper nice gaming keyboard and mouse. I love...  ...
# Date Info                                          April 11, 2022  ...
# Rating                                                          5  ...
#
#                                                                16  \
# Reviewer Name                                                AmXo
# Review Title                    \nGreat pink keyboard and mouse\n
# Review Content  \nMy daughter is very happy. It looks amazing ...
# Date Info                                       September 2, 2021
# Rating                                                          5
#
#                                                                17  \
# Reviewer Name                                             Tammy B
# Review Title                                  \nWorks with Xbox\n
# Review Content  \nQuick delivery and just as described. Works ...
# Date Info                                         August 22, 2021
# Rating                                                          5
#
#                                                                18  \
# Reviewer Name                                             C Smith
# Review Title                                 \nReally Impressed\n
# Review Content  \n\n\n\n\n                    The media could ...
# Date Info                                      September 13, 2021
# Rating                                                          5
#
#                                                                19  \
# Reviewer Name                                               Cindy
# Review Title               \nGreat addition to my new computer.\n
# Review Content  \nIt’s pink. I love pink. It’s exactly what I ...
# Date Info                                            July 7, 2021
# Rating                                                          5
#
#                                                                20  \
# Reviewer Name                                                Tink
# Review Title                                     \nWorks great!\n
# Review Content  \nDaughter loves the pink keyboard and the rai...
# Date Info                                           April 7, 2021
# Rating                                                          5
#
#                                                                21  \
# Reviewer Name                                        Emily Sumner
# Review Title                             \nVery cute for a kid.\n
# Review Content  \nWas really cute! Works well!! Daughter loves...
# Date Info                                         January 4, 2021
# Rating                                                          5
#
#                                                              22  \
# Reviewer Name                                            Janine
# Review Title                                \nWould recommend\n
# Review Content  \nCame in really fast and the quality is good\n
# Date Info                                     November 24, 2020
# Rating                                                        5
#
#                                                                23  \
# Reviewer Name                                           Ryan Nice
# Review Title    \nThe mouse waa not fully functional. Hars to ...
# Review Content  \nThe mouse came with keyboard not in working ...
# Date Info                                       December 28, 2020
# Rating                                                          1
#
#                                       24  \
# Reviewer Name                  julie ann
# Review Title         \nlove the lights\n
# Review Content  \nmy daughter loves it\n
# Date Info              February 27, 2021
# Rating                                 5
#
#                                                                25
# Reviewer Name                                     Allison Leblanc
# Review Title                                      \nI LOVE IT!!\n
# Review Content  \nI love it! It is exactly what I wanted! The ...
# Date Info                                           March 6, 2022
# Rating                                                          5
#
# [5 rows x 26 columns]

# %%
df.dropna(axis=1, inplace=True)
df.head()
# Out:
#                                                                0   \
# Reviewer Name                                     Amazon Customer
# Review Title                                         \nLove it!\n
# Review Content  \nI love this product! It’s cute and fun for s...
# Date Info                                        October 20, 2022
# Rating                                                          5
#
#                                                                1   \
# Reviewer Name                                             crystal
# Review Title                                        \nWork okay\n
# Review Content  \nNot the best quality but great for the price...
# Date Info                                      September 15, 2022
# Rating                                                          4
#
#                                                                2   \
# Reviewer Name                                         Brent ruffo
# Review Title                     \nVery good highly recommend 👍\n
# Review Content  \nThis product has been in my possession for 4...
# Date Info                                         August 12, 2022
# Rating                                                          5
#
#                                                                3   \
# Reviewer Name                                         Jaime Mason
# Review Title                         \nstandard 2000's keyboard\n
# Review Content  \nThe keys are raised extremely high, makes fo...
# Date Info                                        October 16, 2022
# Rating                                                          3
#
#                                                                4   \
# Reviewer Name                                               emily
# Review Title    \nPlastic keys not the best for some games but...
# Review Content                                           \nCute\n
# Date Info                                          April 24, 2022
# Rating                                                          4
#
#                                                                5   \
# Reviewer Name                                     Amazon Customer
# Review Title             \nUgh - didn't know it wasn't wireless\n
# Review Content  \nHad torn through the package only to discove...
# Date Info                                            June 7, 2022
# Rating                                                          3
#
#                                                                6   \
# Reviewer Name                                             Jessica
# Review Title                                 \nGreat additions!\n
# Review Content  \nThis keyboard and mouse duo was purchased to...
# Date Info                                       December 27, 2020
# Rating                                                          4
#
#                                                                7   \
# Reviewer Name                                              Ceetee
# Review Title                       \nPaint comes off after time\n
# Review Content  \nI’ve had this for about a year now and loved...
# Date Info                                             May 1, 2022
# Rating                                                          2
#
#                                                                8   \
# Reviewer Name                                          Dayna Keam
# Review Title                              \nNice cheap keyboard\n
# Review Content  \nWorks good for a cheaper keyboard. Love the ...
# Date Info                                       February 26, 2022
# Rating                                                          5
#
#                                                                9   ...  \
# Reviewer Name                                              Kaeley  ...
# Review Title                                          \nAmazing\n  ...
# Review Content  \nSuper nice gaming keyboard and mouse. I love...  ...
# Date Info                                          April 11, 2022  ...
# Rating                                                          5  ...
#
#                                                                16  \
# Reviewer Name                                                AmXo
# Review Title                    \nGreat pink keyboard and mouse\n
# Review Content  \nMy daughter is very happy. It looks amazing ...
# Date Info                                       September 2, 2021
# Rating                                                          5
#
#                                                                17  \
# Reviewer Name                                             Tammy B
# Review Title                                  \nWorks with Xbox\n
# Review Content  \nQuick delivery and just as described. Works ...
# Date Info                                         August 22, 2021
# Rating                                                          5
#
#                                                                18  \
# Reviewer Name                                             C Smith
# Review Title                                 \nReally Impressed\n
# Review Content  \n\n\n\n\n                    The media could ...
# Date Info                                      September 13, 2021
# Rating                                                          5
#
#                                                                19  \
# Reviewer Name                                               Cindy
# Review Title               \nGreat addition to my new computer.\n
# Review Content  \nIt’s pink. I love pink. It’s exactly what I ...
# Date Info                                            July 7, 2021
# Rating                                                          5
#
#                                                                20  \
# Reviewer Name                                                Tink
# Review Title                                     \nWorks great!\n
# Review Content  \nDaughter loves the pink keyboard and the rai...
# Date Info                                           April 7, 2021
# Rating                                                          5
#
#                                                                21  \
# Reviewer Name                                        Emily Sumner
# Review Title                             \nVery cute for a kid.\n
# Review Content  \nWas really cute! Works well!! Daughter loves...
# Date Info                                         January 4, 2021
# Rating                                                          5
#
#                                                              22  \
# Reviewer Name                                            Janine
# Review Title                                \nWould recommend\n
# Review Content  \nCame in really fast and the quality is good\n
# Date Info                                     November 24, 2020
# Rating                                                        5
#
#                                                                23  \
# Reviewer Name                                           Ryan Nice
# Review Title    \nThe mouse waa not fully functional. Hars to ...
# Review Content  \nThe mouse came with keyboard not in working ...
# Date Info                                       December 28, 2020
# Rating                                                          1
#
#                                       24  \
# Reviewer Name                  julie ann
# Review Title         \nlove the lights\n
# Review Content  \nmy daughter loves it\n
# Date Info              February 27, 2021
# Rating                                 5
#
#                                                                25
# Reviewer Name                                     Allison Leblanc
# Review Title                                      \nI LOVE IT!!\n
# Review Content  \nI love it! It is exactly what I wanted! The ...
# Date Info                                           March 6, 2022
# Rating                                                          5
#
# [5 rows x 26 columns]

# %%
# Transpose the dataframe.
prod_reviews = df.T
print(prod_reviews.head(10))
# Out:
#      Reviewer Name                                       Review Title  \
# 0  Amazon Customer                                       \nLove it!\n
# 1          crystal                                      \nWork okay\n
# 2      Brent ruffo                   \nVery good highly recommend 👍\n
# 3      Jaime Mason                       \nstandard 2000's keyboard\n
# 4            emily  \nPlastic keys not the best for some games but...
# 5  Amazon Customer           \nUgh - didn't know it wasn't wireless\n
# 6          Jessica                               \nGreat additions!\n
# 7           Ceetee                     \nPaint comes off after time\n
# 8       Dayna Keam                            \nNice cheap keyboard\n
# 9           Kaeley                                        \nAmazing\n
#
#                                       Review Content           Date Info  \
# 0  \nI love this product! It’s cute and fun for s...    October 20, 2022
# 1  \nNot the best quality but great for the price...  September 15, 2022
# 2  \nThis product has been in my possession for 4...     August 12, 2022
# 3  \nThe keys are raised extremely high, makes fo...    October 16, 2022
# 4                                           \nCute\n      April 24, 2022
# 5  \nHad torn through the package only to discove...        June 7, 2022
# 6  \nThis keyboard and mouse duo was purchased to...   December 27, 2020
# 7  \nI’ve had this for about a year now and loved...         May 1, 2022
# 8  \nWorks good for a cheaper keyboard. Love the ...   February 26, 2022
# 9  \nSuper nice gaming keyboard and mouse. I love...      April 11, 2022
#
#   Rating
# 0      5
# 1      4
# 2      5
# 3      3
# 4      4
# 5      3
# 6      4
# 7      2
# 8      5
# 9      5

# %%
# Remove special characters from review text.
prod_reviews['Review Title'] = prod_reviews['Review Title'].str.replace('\n','')
prod_reviews['Review Content'] = prod_reviews['Review Content'].str.replace('\n','')
prod_reviews.head(5)
# Out:
#      Reviewer Name                                       Review Title  \
# 0  Amazon Customer                                           Love it!
# 1          crystal                                          Work okay
# 2      Brent ruffo                       Very good highly recommend 👍
# 3      Jaime Mason                           standard 2000's keyboard
# 4            emily  Plastic keys not the best for some games but s...
#
#                                       Review Content           Date Info  \
# 0  I love this product! It’s cute and fun for som...    October 20, 2022
# 1  Not the best quality but great for the price G...  September 15, 2022
# 2  This product has been in my possession for 4 m...     August 12, 2022
# 3  The keys are raised extremely high, makes for ...    October 16, 2022
# 4                                               Cute      April 24, 2022
#
#   Rating
# 0      5
# 1      4
# 2      5
# 3      3
# 4      4

# %%
# Convert dataframe to CSV file.
prod_reviews.to_csv('reviews.csv', index = False, header = True)
